# %% [markdown]
# # ICT Trading Bot Colab task template
#
# Use one notebook per task.

# %%
# !pip install -q -r requirements.txt

# %%
from getpass import getpass
TOKEN = getpass('GitHub PAT: ')
# !git clone https://$TOKEN@github.com/the-lizardking/ict-trading-bot.git
# %cd ict-trading-bot

# %%
from google.colab import userdata
# Example: BYBIT_API_KEY = userdata.get('BYBIT_API_KEY')

# %%
# Run exactly one task here.
# Save outputs to Drive or Hugging Face.
